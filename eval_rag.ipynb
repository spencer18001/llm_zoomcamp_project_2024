# %%
# %%capture
# !pip install google-generativeai
# !wget -O llm-results-prompt.csv https://github.com/spencer18001/llm_zoomcamp_project_2024/blob/main/llm-results-prompt.csv?raw=1
# !wget -O llm-results-prompt2.csv https://github.com/spencer18001/llm_zoomcamp_project_2024/blob/main/llm-results-prompt2.csv?raw=1

# %%
import json
from tqdm.auto import tqdm
import pandas as pd
from google.colab import userdata
import google.generativeai as genai

# %%
genai.configure(api_key=userdata.get('GEMINI_API_KEY'))
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
prompt_template = """
You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks (not including json quotes):

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %%
df_results_prompt = pd.read_csv("llm-results-prompt.csv")
results_prompt = df_results_prompt.to_dict(orient='records')
df_results_prompt
# Out:
#                                              question  \
# 0   Why did the narrator's companion lock the door...
# 1   What was the sound that the narrator heard aft...
# 2                         What is stored in the safe?
# 3             Who is the speaker threatening and why?
# 4   Why would the man in the story need to stand o...
# 5   What is the source of the woman's fear and ter...
# 6   Are they referring to the windows of a specifi...
# 7   Who was the half-pay major of marines that the...
# 8   What did Holmes hit with such force that cause...
# 9      How did the lady react to the man's statement?
# 10         What did the man throw into the fireplace?
# 11                                   What was bolted?
# 12  Who is the doctor that Holmes and the narrator...
# 13  What was the Farintosh case about and what hap...
# 14         What did Holmes bring with him to the bed?
# 15  Who is the speaker in this passage, and what i...
# 16  Why would the builder connect the ventilator t...
# 17  What was the total income of the deceased wife...
# 18  What was the sinister quest that the narrator ...
# 19        What was the terrible occupant of the safe?
#
#                                                answer  document
# 0   According to context: The narrator's companion...        44
# 1   After hearing Holmes make something resembling...        47
# 2   According to the context provided, Dr. Grimesb...       110
# 3   The speaker is addressing Sherlock Holmes befo...        77
# 4   The man in the story needed to stand on a chai...       159
# 5   The woman's fear and terror stem from hearing ...        11
# 6   Based on the CONTEXT provided from "The Advent...       116
# 7   According to the original text "When Dr. Roylo...        35
# 8   The CONTEXT does not provide specific informat...       143
# 9   Given that there was no direct dialogue or exp...        14
# 10  In the fireplace, Drusilla Bell had discarded ...        78
# 11  The noose was bolted to something along the wa...        99
# 12  The doctor that Holmes and the narrator have m...        91
# 13  The Farintosh case involved a woman named Mrs....        19
# 14  Based on the information provided in the CONTE...       138
# 15  The speaker in this passage is Dr. John H. Wat...        75
# 16  The CONTEXT does not provide specific reasons ...       107
# 17  To provide an accurate answer to this question...        81
# 18  The narrator and his companion were engaged in...        85
# 19  The terrible occupant of the safe is not expli...       160

# %%
evaluations_prompt = {}

# %%
for record in tqdm(results_prompt):
    doc_id = record["document"]
    if doc_id in evaluations_prompt:
        continue

    prompt = prompt_template.format(**record)
    response = model.generate_content(prompt, safety_settings=[
        {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_NONE"}
    ])
    evaluations_prompt[doc_id] = response.text
len(evaluations_prompt)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 20

# %%
evaluations_prompt[110]
# Out:
# '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "The generated answer describes the contents of Dr. Roylott\'s chamber and mentions the safe, but it explicitly states that there is no information about what\'s inside the safe. This makes the answer non-relevant as it doesn\'t provide any information about the contents of the safe."\n} \n'

# %%
json_evaluations_prompt = []
for doc_id, str_eval in evaluations_prompt.items():
    json_eval = json.loads(str_eval)
    json_evaluations_prompt.append(json_eval)
len(json_evaluations_prompt)
# Out:
# 20

# %%
df_evaluations_prompt = pd.DataFrame(json_evaluations_prompt)

# %%
df_evaluations_prompt.Relevance.value_counts()
# Out:
# Relevance
# NON_RELEVANT       8
# RELEVANT           6
# PARTLY_RELEVANT    6
# Name: count, dtype: int64

# %%
df_results_prompt2 = pd.read_csv("llm-results-prompt2.csv")
results_prompt2 = df_results_prompt2.to_dict(orient='records')

# %%
evaluations_prompt2 = {}

# %%
for record in tqdm(results_prompt2):
    doc_id = record["document"]
    if doc_id in evaluations_prompt2:
        continue

    prompt = prompt_template.format(**record)
    response = model.generate_content(prompt, safety_settings=[
        {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_NONE"}
    ])
    evaluations_prompt2[doc_id] = response.text
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
json_evaluations_prompt2 = []
for doc_id, str_eval in evaluations_prompt2.items():
    json_eval = json.loads(str_eval)
    json_evaluations_prompt2.append(json_eval)
len(json_evaluations_prompt2)
# Out:
# 20

# %%
df_evaluations_prompt2 = pd.DataFrame(json_evaluations_prompt2)

# %%
df_evaluations_prompt2.Relevance.value_counts()
# Out:
# Relevance
# NON_RELEVANT       11
# PARTLY_RELEVANT     5
# RELEVANT            4
# Name: count, dtype: int64
